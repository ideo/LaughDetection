# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,8)

# %%
import pandas as pd
df = pd.read_csv('test_lunch.csv',names=['time','score'])

# %%
df.plot()

# %%
(df['score']>0.5).mean()
# Out:
# 0.5736434108527132
